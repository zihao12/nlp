# %%
from sklearn.datasets import make_moons
import pandas as pd
import numpy as np

import torch
from torch.autograd import Variable
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

def to_categorical(y, num_classes):
    """1-hot encodes a tensor"""
    return np.eye(num_classes, dtype='uint8')[y]

X, y = make_moons(n_samples=1000, noise=.1)
y = to_categorical(y, 2)

# %%
class PrepareData(Dataset):

    def __init__(self, X, y):
        if not torch.is_tensor(X):
            self.X = torch.from_numpy(X)
        if not torch.is_tensor(y):
            self.y = torch.from_numpy(y)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

ds = PrepareData(X=X, y=y)

# %%
ds = DataLoader(ds, batch_size=50, shuffle=True)

# %%
ds.X.shape
# Out:
# torch.Size([1000, 2])

# %%
for i, (x,y) in enumerate(ds):
    print(x)
# Out:
# tensor([2.0071, 0.6378], dtype=torch.float64)
# tensor([ 0.3032, -0.4039], dtype=torch.float64)
# tensor([-1.0787,  0.4671], dtype=torch.float64)
# tensor([-0.4528,  0.7828], dtype=torch.float64)
# tensor([0.0729, 1.0115], dtype=torch.float64)
# tensor([ 0.3762, -0.5481], dtype=torch.float64)
# tensor([ 0.5283, -0.5016], dtype=torch.float64)
# tensor([-0.1861,  0.9851], dtype=torch.float64)
# tensor([-1.0152,  0.1408], dtype=torch.float64)
# tensor([ 0.4122, -0.2463], dtype=torch.float64)
# tensor([-0.9174,  0.3219], dtype=torch.float64)
# tensor([0.2573, 0.0279], dtype=torch.float64)
# tensor([ 0.3768, -0.3763], dtype=torch.float64)
# tensor([ 1.6121, -0.2965], dtype=torch.float64)
# tensor([0.7915, 0.2671], dtype=torch.float64)
# tensor([ 0.6716, -0.4827], dtype=torch.float64)
# tensor([ 1.1452, -0.4524], dtype=torch.float64)
# tensor([1.8492, 0.5295], dtype=torch.float64)
# tensor([2.1897, 0.4616], dtype=torch.float64)
# tensor([1.0012, 0.2881], dtype=torch.float64)
# tensor([-0.7258,  0.5479], dtype=torch.float64)
# tensor([ 0.6935, -0.3050], dtype=torch.float64)
# tensor([1.9946, 0.0034], dtype=torch.float64)
# tensor([1.0300, 0.1241], dtype=torch.float64)
# tensor([-0.7691,  0.5739], dtype=torch.float64)
# tensor([-0.7764,  0.5138], dtype=torch.float64)
# tensor([0.1724, 0.1679], dtype=torch.float64)
# tensor([0.9841, 0.0274], dtype=torch.float64)
# tensor([-0.5192,  0.9735], dtype=torch.float64)
# tensor([1.8256, 0.2243], dtype=torch.float64)
# tensor([0.0476, 1.0835], dtype=torch.float64)
# tensor([ 1.6451, -0.3274], dtype=torch.float64)
# tensor([ 0.3317, -0.2717], dtype=torch.float64)
# tensor([-0.5177,  1.0143], dtype=torch.float64)
# tensor([0.4348, 0.9365], dtype=torch.float64)
# tensor([0.6198, 0.6806], dtype=torch.float64)
# tensor([-1.0101,  0.3369], dtype=torch.float64)
# tensor([0.5919, 0.8194], dtype=torch.float64)
# tensor([-0.0047,  0.1255], dtype=torch.float64)
# tensor([-0.3756,  0.9064], dtype=torch.float64)
# tensor([1.0645, 0.0772], dtype=torch.float64)
# tensor([-0.2865,  1.0192], dtype=torch.float64)
# tensor([1.8658, 0.0221], dtype=torch.float64)
# tensor([0.2846, 0.8818], dtype=torch.float64)
# tensor([-0.3340,  0.8557], dtype=torch.float64)
# tensor([-0.1468,  1.1227], dtype=torch.float64)
# tensor([1.8340, 0.2269], dtype=torch.float64)
# tensor([ 0.7241, -0.4504], dtype=torch.float64)
# tensor([ 1.4416, -0.5792], dtype=torch.float64)
# tensor([1.9556, 0.0766], dtype=torch.float64)
# tensor([ 1.1883, -0.4702], dtype=torch.float64)
# tensor([0.0972, 1.0249], dtype=torch.float64)
# tensor([0.3883, 0.9544], dtype=torch.float64)
# tensor([1.9989, 0.2145], dtype=torch.float64)
# tensor([1.9985, 0.2666], dtype=torch.float64)
# tensor([0.6098, 0.7124], dtype=torch.float64)
# tensor([0.3545, 0.9941], dtype=torch.float64)
# tensor([ 0.2682, -0.1296], dtype=torch.float64)
# tensor([-1.0002,  0.0363], dtype=torch.float64)
# tensor([ 0.8486, -0.4814], dtype=torch.float64)
# tensor([-0.1171,  1.0920], dtype=torch.float64)
# tensor([0.0521, 0.1551], dtype=torch.float64)
# tensor([0.8253, 0.3985], dtype=torch.float64)
# tensor([ 1.0160, -0.5527], dtype=torch.float64)
# tensor([-0.9181,  0.2576], dtype=torch.float64)
# tensor([-0.7295,  0.8197], dtype=torch.float64)
# tensor([ 0.5061, -0.4238], dtype=torch.float64)
# tensor([-0.9964,  0.0735], dtype=torch.float64)
# tensor([0.8740, 0.1506], dtype=torch.float64)
# tensor([ 0.2445, -0.0668], dtype=torch.float64)
# tensor([0.0325, 0.7224], dtype=torch.float64)
# tensor([ 0.2199, -0.0226], dtype=torch.float64)
# tensor([0.3488, 1.0832], dtype=torch.float64)
# tensor([ 1.7498, -0.1287], dtype=torch.float64)
# tensor([ 0.4185, -0.5402], dtype=torch.float64)
# tensor([-0.1814,  0.9234], dtype=torch.float64)
# tensor([1.8014, 0.2163], dtype=torch.float64)
# tensor([ 1.7684, -0.1875], dtype=torch.float64)
# tensor([ 1.8783, -0.0726], dtype=torch.float64)
# tensor([ 0.8497, -0.4821], dtype=torch.float64)
# tensor([0.6045, 0.8164], dtype=torch.float64)
# tensor([-0.5571,  0.8666], dtype=torch.float64)
# tensor([0.7500, 0.8709], dtype=torch.float64)
# tensor([-0.0860,  0.3071], dtype=torch.float64)
# tensor([0.1190, 0.8865], dtype=torch.float64)
# tensor([ 1.4575, -0.4385], dtype=torch.float64)
# tensor([-1.6494e-05,  2.6195e-01], dtype=torch.float64)
# tensor([2.0112, 0.2524], dtype=torch.float64)
# tensor([2.1041, 0.2837], dtype=torch.float64)
# tensor([0.4455, 0.9049], dtype=torch.float64)
# tensor([ 0.9814, -0.3819], dtype=torch.float64)
# tensor([0.8540, 0.6569], dtype=torch.float64)
# tensor([0.0148, 0.9533], dtype=torch.float64)
# tensor([-0.6865,  0.7366], dtype=torch.float64)
# tensor([0.1791, 0.9963], dtype=torch.float64)
# tensor([1.7464, 0.4709], dtype=torch.float64)
# tensor([-0.7679,  0.6538], dtype=torch.float64)
# tensor([-1.0574,  0.3261], dtype=torch.float64)
# tensor([0.9700, 0.4008], dtype=torch.float64)
# tensor([ 1.7665, -0.1350], dtype=torch.float64)
# tensor([-0.7485,  0.4452], dtype=torch.float64)
# tensor([ 0.6185, -0.5628], dtype=torch.float64)
# tensor([ 1.1172, -0.0432], dtype=torch.float64)
# tensor([ 1.1058, -0.5432], dtype=torch.float64)
# tensor([-0.1509,  0.9363], dtype=torch.float64)
# tensor([-0.0593,  0.4587], dtype=torch.float64)
# tensor([1.8276, 0.1021], dtype=torch.float64)
# tensor([0.7500, 0.6119], dtype=torch.float64)
# tensor([-1.0175,  0.2418], dtype=torch.float64)
# tensor([-0.7888,  0.1761], dtype=torch.float64)
# tensor([-0.6707,  0.8358], dtype=torch.float64)
# tensor([-0.9406,  0.3831], dtype=torch.float64)
# tensor([-0.3899,  0.8890], dtype=torch.float64)
# tensor([ 0.1924, -0.2543], dtype=torch.float64)
# tensor([0.4830, 0.7507], dtype=torch.float64)
# tensor([-0.9171,  0.3699], dtype=torch.float64)
# tensor([0.6361, 0.7674], dtype=torch.float64)
# tensor([1.0387, 0.4014], dtype=torch.float64)
# tensor([ 0.2345, -0.0415], dtype=torch.float64)
# tensor([-0.6917,  0.8882], dtype=torch.float64)
# tensor([0.2459, 0.0367], dtype=torch.float64)
# tensor([-0.7663,  0.5387], dtype=torch.float64)
# tensor([1.0579, 0.1885], dtype=torch.float64)
# tensor([ 1.1285, -0.4658], dtype=torch.float64)
# tensor([-0.6575,  0.7426], dtype=torch.float64)
# tensor([-0.3287,  1.0610], dtype=torch.float64)
# tensor([-0.2296,  1.0307], dtype=torch.float64)
# tensor([-0.5438,  0.9729], dtype=torch.float64)
# tensor([0.0753, 0.9268], dtype=torch.float64)
# tensor([ 1.4297, -0.1647], dtype=torch.float64)
# tensor([ 1.5648, -0.2816], dtype=torch.float64)
# tensor([2.0172, 0.2100], dtype=torch.float64)
# tensor([-0.0786,  0.1054], dtype=torch.float64)
# tensor([0.2842, 1.1806], dtype=torch.float64)
# tensor([ 0.2802, -0.3109], dtype=torch.float64)
# tensor([ 0.8540, -0.5736], dtype=torch.float64)
# tensor([ 1.7132, -0.1757], dtype=torch.float64)
# tensor([ 0.1444, -0.0566], dtype=torch.float64)
# tensor([2.0834, 0.1552], dtype=torch.float64)
# tensor([0.6095, 0.8021], dtype=torch.float64)
# tensor([0.4387, 0.8107], dtype=torch.float64)
# tensor([-0.8676,  0.2126], dtype=torch.float64)
# tensor([0.5783, 0.8734], dtype=torch.float64)
# tensor([-0.8546,  0.5421], dtype=torch.float64)
# tensor([ 0.5748, -0.4084], dtype=torch.float64)
# tensor([ 0.2730, -0.1775], dtype=torch.float64)
# tensor([-0.2732,  0.8760], dtype=torch.float64)
# tensor([0.7409, 0.7992], dtype=torch.float64)
# tensor([1.1114, 0.1151], dtype=torch.float64)
# tensor([ 1.4489, -0.2858], dtype=torch.float64)
# tensor([ 0.1034, -0.0611], dtype=torch.float64)
# tensor([-0.1174,  0.4416], dtype=torch.float64)
# tensor([1.9885, 0.4096], dtype=torch.float64)
# tensor([1.9479, 0.3785], dtype=torch.float64)
# tensor([ 0.0911, -0.0975], dtype=torch.float64)
# tensor([0.0376, 0.1393], dtype=torch.float64)
# tensor([-0.5282,  0.8576], dtype=torch.float64)
# tensor([0.2399, 0.1155], dtype=torch.float64)
# tensor([ 1.6701, -0.1000], dtype=torch.float64)
# tensor([1.0529, 0.2254], dtype=torch.float64)
# tensor([ 1.2092, -0.4475], dtype=torch.float64)
# tensor([ 1.9341, -0.2122], dtype=torch.float64)
# tensor([0.2482, 0.0646], dtype=torch.float64)
# tensor([-0.0489,  0.9833], dtype=torch.float64)
# tensor([ 0.4175, -0.2518], dtype=torch.float64)
# tensor([-1.0436,  0.3366], dtype=torch.float64)
# tensor([0.1540, 0.2531], dtype=torch.float64)
# tensor([ 0.9407, -0.3817], dtype=torch.float64)
# tensor([ 1.6306, -0.3975], dtype=torch.float64)
# tensor([ 0.5814, -0.3922], dtype=torch.float64)
# tensor([1.7772, 0.0347], dtype=torch.float64)
# tensor([0.7225, 0.9844], dtype=torch.float64)
# tensor([1.0027, 0.3570], dtype=torch.float64)
# tensor([-0.9018,  0.7581], dtype=torch.float64)
# tensor([ 1.6610, -0.4069], dtype=torch.float64)
# tensor([-0.3586,  0.8651], dtype=torch.float64)
# tensor([-0.4469,  0.9361], dtype=torch.float64)
# tensor([-0.4149,  1.0257], dtype=torch.float64)
# tensor([ 0.2513, -0.0155], dtype=torch.float64)
# tensor([0.5738, 0.7565], dtype=torch.float64)
# tensor([ 0.9660, -0.5166], dtype=torch.float64)
# tensor([-0.5946,  1.0404], dtype=torch.float64)
# tensor([0.1467, 1.1746], dtype=torch.float64)
# tensor([ 0.5800, -0.5432], dtype=torch.float64)
# tensor([-0.6441,  0.8357], dtype=torch.float64)
# tensor([0.1601, 0.8404], dtype=torch.float64)
# tensor([0.9561, 0.6242], dtype=torch.float64)
# tensor([-0.7989,  0.3978], dtype=torch.float64)
# tensor([1.9437, 0.3939], dtype=torch.float64)
# tensor([2.0113, 0.2970], dtype=torch.float64)
# tensor([-1.0061,  0.0934], dtype=torch.float64)
# tensor([ 1.8916, -0.0398], dtype=torch.float64)
# tensor([ 1.4160, -0.4937], dtype=torch.float64)
# tensor([-0.7597,  0.5392], dtype=torch.float64)
# tensor([ 1.1281, -0.5548], dtype=torch.float64)
# tensor([ 1.8072, -0.1689], dtype=torch.float64)
# tensor([0.9353, 0.2859], dtype=torch.float64)
# tensor([0.0313, 0.1256], dtype=torch.float64)
# tensor([-0.1206,  0.8798], dtype=torch.float64)
# tensor([ 0.4812, -0.2708], dtype=torch.float64)
# tensor([1.9938, 0.0697], dtype=torch.float64)
# tensor([ 0.5086, -0.6472], dtype=torch.float64)
# tensor([ 1.6776, -0.3966], dtype=torch.float64)
# tensor([ 1.0925, -0.4841], dtype=torch.float64)
# tensor([0.2788, 0.2337], dtype=torch.float64)
# tensor([-0.5267,  0.8011], dtype=torch.float64)
# tensor([0.4452, 0.7094], dtype=torch.float64)
# tensor([ 0.9459, -0.5368], dtype=torch.float64)
# tensor([-0.0203,  0.1523], dtype=torch.float64)
# tensor([-0.5365,  0.7976], dtype=torch.float64)
# tensor([-0.8795, -0.0551], dtype=torch.float64)
# tensor([0.5323, 0.9291], dtype=torch.float64)
# tensor([1.2531, 0.1441], dtype=torch.float64)
# tensor([ 1.5004, -0.3881], dtype=torch.float64)
# tensor([-0.1349,  0.9406], dtype=torch.float64)
# tensor([2.0203, 0.2922], dtype=torch.float64)
# tensor([0.0199, 1.0554], dtype=torch.float64)
# tensor([0.6755, 0.5067], dtype=torch.float64)
# tensor([ 0.8908, -0.3789], dtype=torch.float64)
# tensor([0.5963, 0.7151], dtype=torch.float64)
# tensor([0.7247, 0.7765], dtype=torch.float64)
# tensor([0.7499, 0.6608], dtype=torch.float64)
# tensor([1.1252, 0.1042], dtype=torch.float64)
# tensor([ 0.8236, -0.5120], dtype=torch.float64)
# tensor([0.3210, 0.9744], dtype=torch.float64)
# tensor([1.8049, 0.4712], dtype=torch.float64)
# tensor([0.3296, 0.9092], dtype=torch.float64)
# tensor([-0.6591,  0.7130], dtype=torch.float64)
# tensor([-0.1102,  0.4675], dtype=torch.float64)
# tensor([ 1.5321, -0.4442], dtype=torch.float64)
# tensor([ 0.6514, -0.5577], dtype=torch.float64)
# tensor([-0.8409,  0.3221], dtype=torch.float64)
# tensor([0.0259, 1.1181], dtype=torch.float64)
# tensor([ 0.0358, -0.0624], dtype=torch.float64)
# tensor([-0.0771,  1.1020], dtype=torch.float64)
# tensor([ 1.2944, -0.3781], dtype=torch.float64)
# tensor([ 0.3824, -0.3151], dtype=torch.float64)
# tensor([ 0.3762, -0.4238], dtype=torch.float64)
# tensor([-0.0512,  0.1486], dtype=torch.float64)
# tensor([ 1.2520, -0.4468], dtype=torch.float64)
# tensor([-0.4023,  0.8723], dtype=torch.float64)
# tensor([-0.8446,  0.1522], dtype=torch.float64)
# tensor([-0.4448,  0.9282], dtype=torch.float64)
# tensor([ 0.9324, -0.0061], dtype=torch.float64)
# tensor([0.8355, 0.7479], dtype=torch.float64)
# tensor([ 0.6732, -0.6235], dtype=torch.float64)
# tensor([ 1.3831, -0.4679], dtype=torch.float64)
# tensor([-0.8357,  0.5703], dtype=torch.float64)
# tensor([0.7691, 0.7841], dtype=torch.float64)
# tensor([-0.4229,  0.9561], dtype=torch.float64)
# tensor([0.1807, 0.9171], dtype=torch.float64)
# tensor([-0.8346,  0.2079], dtype=torch.float64)
# tensor([-1.0827,  0.1403], dtype=torch.float64)
# tensor([-0.9328,  0.2547], dtype=torch.float64)
# tensor([0.9242, 0.4065], dtype=torch.float64)
# tensor([ 0.7267, -0.5193], dtype=torch.float64)
# tensor([2.0144, 0.6460], dtype=torch.float64)
# tensor([-0.5470,  0.8905], dtype=torch.float64)
# tensor([ 1.2366, -0.4700], dtype=torch.float64)
# tensor([-0.5908,  0.8056], dtype=torch.float64)
# tensor([ 1.0595, -0.4793], dtype=torch.float64)
# tensor([1.6176, 0.1248], dtype=torch.float64)
# tensor([-0.4878,  0.9293], dtype=torch.float64)
# tensor([0.2031, 1.0146], dtype=torch.float64)
# tensor([ 1.4753, -0.3657], dtype=torch.float64)
# tensor([ 0.6692, -0.4834], dtype=torch.float64)
# tensor([ 0.5176, -0.2375], dtype=torch.float64)
# tensor([ 0.6900, -0.4919], dtype=torch.float64)
# tensor([-0.7683,  0.4895], dtype=torch.float64)
# tensor([ 0.6697, -0.3143], dtype=torch.float64)
# tensor([-0.9482, -0.0164], dtype=torch.float64)
# tensor([ 1.0647, -0.4850], dtype=torch.float64)
# tensor([-0.6477,  0.5152], dtype=torch.float64)
# tensor([2.0661, 0.5277], dtype=torch.float64)
# tensor([-0.8265,  0.6330], dtype=torch.float64)
# tensor([2.0361, 0.0631], dtype=torch.float64)
# tensor([-0.4273,  0.9965], dtype=torch.float64)
# tensor([-0.9571,  0.0643], dtype=torch.float64)
# tensor([0.9400, 0.1026], dtype=torch.float64)
# tensor([0.9132, 0.3774], dtype=torch.float64)
# tensor([ 0.2329, -0.1201], dtype=torch.float64)
# tensor([0.3764, 0.0036], dtype=torch.float64)
# tensor([0.7939, 0.7526], dtype=torch.float64)
# tensor([0.8331, 0.6266], dtype=torch.float64)
# tensor([ 0.2569, -0.0245], dtype=torch.float64)
# tensor([1.9125, 0.5968], dtype=torch.float64)
# tensor([-0.7277,  0.4006], dtype=torch.float64)
# tensor([ 0.8494, -0.4010], dtype=torch.float64)
# tensor([-0.0598,  1.0039], dtype=torch.float64)
# tensor([ 1.8496, -0.1845], dtype=torch.float64)
# tensor([ 0.9032, -0.5735], dtype=torch.float64)
# tensor([-0.0996,  0.3078], dtype=torch.float64)
# tensor([ 0.1602, -0.0047], dtype=torch.float64)
# tensor([0.0848, 1.0995], dtype=torch.float64)
# tensor([0.2261, 0.9429], dtype=torch.float64)
# tensor([0.1358, 0.1819], dtype=torch.float64)
# tensor([-0.5237,  0.8345], dtype=torch.float64)
# tensor([-0.0183,  1.1215], dtype=torch.float64)
# tensor([-0.7428,  0.1064], dtype=torch.float64)
# tensor([-0.2591,  0.8046], dtype=torch.float64)
# tensor([ 0.6904, -0.6258], dtype=torch.float64)
# tensor([-0.2830,  0.9503], dtype=torch.float64)
# tensor([-0.0038,  1.0763], dtype=torch.float64)
# tensor([ 1.5475, -0.2580], dtype=torch.float64)
# tensor([ 1.2588, -0.5732], dtype=torch.float64)
# tensor([0.1383, 0.2288], dtype=torch.float64)
# tensor([1.8275, 0.2339], dtype=torch.float64)
# tensor([0.4837, 0.7527], dtype=torch.float64)
# tensor([-0.2708,  1.0271], dtype=torch.float64)
# tensor([ 1.0484, -0.5329], dtype=torch.float64)
# tensor([0.5139, 0.9251], dtype=torch.float64)
# tensor([ 1.9030, -0.1022], dtype=torch.float64)
# tensor([0.9727, 0.1760], dtype=torch.float64)
# tensor([-0.2041,  0.8406], dtype=torch.float64)
# tensor([-1.2476,  0.1248], dtype=torch.float64)
# tensor([ 0.1819, -0.3292], dtype=torch.float64)
# tensor([0.6170, 0.8371], dtype=torch.float64)
# tensor([1.9602, 0.0902], dtype=torch.float64)
# tensor([ 1.2889, -0.6399], dtype=torch.float64)
# tensor([0.0550, 0.8344], dtype=torch.float64)
# tensor([-0.3672,  0.7964], dtype=torch.float64)
# tensor([-0.8015, -0.1079], dtype=torch.float64)
# tensor([0.8115, 0.4865], dtype=torch.float64)
# tensor([0.0419, 0.4525], dtype=torch.float64)
# tensor([-0.7538,  0.6138], dtype=torch.float64)
# tensor([-0.9869, -0.1467], dtype=torch.float64)
# tensor([-1.0843,  0.4528], dtype=torch.float64)
# tensor([ 1.6343, -0.0608], dtype=torch.float64)
# tensor([ 1.4965, -0.2610], dtype=torch.float64)
# tensor([ 0.7498, -0.4150], dtype=torch.float64)
# tensor([ 0.7495, -0.3817], dtype=torch.float64)
# tensor([0.1727, 0.8195], dtype=torch.float64)
# tensor([ 1.4812, -0.2747], dtype=torch.float64)
# tensor([ 0.2714, -0.3899], dtype=torch.float64)
# tensor([-0.3911,  0.8694], dtype=torch.float64)
# tensor([ 1.0045, -0.4994], dtype=torch.float64)
# tensor([0.1597, 0.0660], dtype=torch.float64)
# tensor([ 1.5801, -0.1914], dtype=torch.float64)
# tensor([-1.1478,  0.0420], dtype=torch.float64)
# tensor([-0.8279,  0.3919], dtype=torch.float64)
# tensor([ 1.6862, -0.2493], dtype=torch.float64)
# tensor([-0.1946,  0.8814], dtype=torch.float64)
# tensor([ 1.3815, -0.5639], dtype=torch.float64)
# tensor([ 1.1474, -0.6096], dtype=torch.float64)
# tensor([-0.8131,  0.1802], dtype=torch.float64)
# tensor([0.1662, 0.2312], dtype=torch.float64)
# tensor([ 0.8549, -0.3868], dtype=torch.float64)
# tensor([0.9011, 0.6580], dtype=torch.float64)
# tensor([ 1.6838, -0.2488], dtype=torch.float64)
# tensor([ 1.7726, -0.0182], dtype=torch.float64)
# tensor([ 1.4832, -0.3657], dtype=torch.float64)
# tensor([-0.8963,  0.0826], dtype=torch.float64)
# tensor([ 0.5134, -0.2800], dtype=torch.float64)
# tensor([0.9795, 0.4775], dtype=torch.float64)
# tensor([-0.8268, -0.0369], dtype=torch.float64)
# tensor([-0.1281,  0.9917], dtype=torch.float64)
# tensor([0.9297, 0.3192], dtype=torch.float64)
# tensor([-0.7364,  0.5836], dtype=torch.float64)
# tensor([-0.0562,  0.8673], dtype=torch.float64)
# tensor([0.9635, 0.2963], dtype=torch.float64)
# tensor([0.0497, 0.0588], dtype=torch.float64)
# tensor([0.8997, 0.3015], dtype=torch.float64)
# tensor([0.2243, 0.8317], dtype=torch.float64)
# tensor([-0.2178,  0.9204], dtype=torch.float64)
# tensor([1.0541, 0.2678], dtype=torch.float64)
# tensor([0.0855, 0.2933], dtype=torch.float64)
# tensor([ 1.7060, -0.0786], dtype=torch.float64)
# tensor([0.4333, 0.8927], dtype=torch.float64)
# tensor([-0.9832,  0.1388], dtype=torch.float64)
# tensor([0.8729, 0.6353], dtype=torch.float64)
# tensor([ 1.8181, -0.1483], dtype=torch.float64)
# tensor([0.1409, 0.0635], dtype=torch.float64)
# tensor([0.0132, 0.4133], dtype=torch.float64)
# tensor([-0.3936,  1.0082], dtype=torch.float64)
# tensor([ 0.4705, -0.3628], dtype=torch.float64)
# tensor([1.0058, 0.4869], dtype=torch.float64)
# tensor([-0.3871,  0.8946], dtype=torch.float64)
# tensor([-1.0398,  0.3727], dtype=torch.float64)
# tensor([ 1.4847, -0.4461], dtype=torch.float64)
# tensor([ 0.2624, -0.1410], dtype=torch.float64)
# tensor([-1.0255,  0.3731], dtype=torch.float64)
# tensor([ 1.7004, -0.1210], dtype=torch.float64)
# tensor([0.1390, 1.0610], dtype=torch.float64)
# tensor([ 0.6248, -0.2796], dtype=torch.float64)
# tensor([ 0.8000, -0.3645], dtype=torch.float64)
# tensor([ 1.6505, -0.3879], dtype=torch.float64)
# tensor([1.8421, 0.0520], dtype=torch.float64)
# tensor([ 1.2322, -0.2263], dtype=torch.float64)
# tensor([-1.0196,  0.1562], dtype=torch.float64)
# tensor([0.2879, 1.0437], dtype=torch.float64)
# tensor([-0.1676,  0.7796], dtype=torch.float64)
# tensor([ 0.2262, -0.1687], dtype=torch.float64)
# tensor([0.9862, 0.4384], dtype=torch.float64)
# tensor([ 1.2190, -0.7202], dtype=torch.float64)
# tensor([ 1.6936, -0.1399], dtype=torch.float64)
# tensor([ 0.2686, -0.1281], dtype=torch.float64)
# tensor([ 0.0853, -0.1595], dtype=torch.float64)
# tensor([ 1.6840, -0.2211], dtype=torch.float64)
# tensor([0.1248, 0.1274], dtype=torch.float64)
# tensor([-0.5011,  0.8114], dtype=torch.float64)
# tensor([-0.0794,  1.0571], dtype=torch.float64)
# tensor([-0.9361,  0.0934], dtype=torch.float64)
# tensor([ 1.3512, -0.4943], dtype=torch.float64)
# tensor([ 0.7473, -0.3996], dtype=torch.float64)
# tensor([ 1.0237, -0.5449], dtype=torch.float64)
# tensor([ 1.3905, -0.3606], dtype=torch.float64)
# tensor([0.6909, 0.5237], dtype=torch.float64)
# tensor([2.0095, 0.3586], dtype=torch.float64)
# tensor([1.7848, 0.1360], dtype=torch.float64)
# tensor([0.5966, 0.7359], dtype=torch.float64)
# tensor([ 0.8556, -0.4177], dtype=torch.float64)
# tensor([ 1.6090, -0.0125], dtype=torch.float64)
# tensor([-0.0674,  0.0977], dtype=torch.float64)
# tensor([0.2185, 0.2933], dtype=torch.float64)
# tensor([-0.0459,  0.1374], dtype=torch.float64)
# tensor([ 1.6288, -0.2558], dtype=torch.float64)
# tensor([ 0.6563, -0.3925], dtype=torch.float64)
# tensor([2.1256, 0.5171], dtype=torch.float64)
# tensor([0.2402, 0.9909], dtype=torch.float64)
# tensor([-0.9281,  0.4907], dtype=torch.float64)
# tensor([1.9360, 0.2319], dtype=torch.float64)
# tensor([0.4376, 0.9447], dtype=torch.float64)
# tensor([ 1.6078, -0.1735], dtype=torch.float64)
# tensor([-0.3453,  0.9657], dtype=torch.float64)
# tensor([1.1519, 0.1929], dtype=torch.float64)
# tensor([2.0023, 0.1614], dtype=torch.float64)
# tensor([1.8663, 0.2996], dtype=torch.float64)
# tensor([-0.5452,  0.8277], dtype=torch.float64)
# tensor([0.5949, 0.8280], dtype=torch.float64)
# tensor([0.8374, 0.7182], dtype=torch.float64)
# tensor([0.9236, 0.3694], dtype=torch.float64)
# tensor([1.9758, 0.0945], dtype=torch.float64)
# tensor([0.7626, 0.7552], dtype=torch.float64)
# tensor([0.6703, 0.6166], dtype=torch.float64)
# tensor([0.9834, 0.0733], dtype=torch.float64)
# tensor([ 1.9317, -0.0777], dtype=torch.float64)
# tensor([1.7150, 0.0160], dtype=torch.float64)
# tensor([0.7841, 0.6453], dtype=torch.float64)
# tensor([ 1.4213, -0.1994], dtype=torch.float64)
# tensor([0.1683, 0.0651], dtype=torch.float64)
# tensor([-0.5113,  0.7192], dtype=torch.float64)
# tensor([ 0.8579, -0.4521], dtype=torch.float64)
# tensor([0.0563, 1.2191], dtype=torch.float64)
# tensor([-0.6002,  1.0073], dtype=torch.float64)
# tensor([ 0.9709, -0.3484], dtype=torch.float64)
# tensor([-0.2308,  0.9449], dtype=torch.float64)
# tensor([0.1614, 0.9856], dtype=torch.float64)
# tensor([ 1.7237, -0.0780], dtype=torch.float64)
# tensor([0.1670, 0.5149], dtype=torch.float64)
# tensor([ 1.9322, -0.0497], dtype=torch.float64)
# tensor([0.0550, 0.2354], dtype=torch.float64)
# tensor([ 0.5768, -0.6757], dtype=torch.float64)
# tensor([ 1.7653, -0.1289], dtype=torch.float64)
# tensor([ 1.3082, -0.4531], dtype=torch.float64)
# tensor([0.9919, 0.5422], dtype=torch.float64)
# tensor([-0.7798,  0.7231], dtype=torch.float64)
# tensor([-0.9159,  0.1208], dtype=torch.float64)
# tensor([ 1.4815, -0.2358], dtype=torch.float64)
# tensor([ 0.3534, -0.0130], dtype=torch.float64)
# tensor([-0.7099,  1.0695], dtype=torch.float64)
# tensor([-0.5688,  0.9038], dtype=torch.float64)
# tensor([ 1.3522, -0.2520], dtype=torch.float64)
# tensor([-0.4210,  0.8204], dtype=torch.float64)
# tensor([0.8200, 0.5342], dtype=torch.float64)
# tensor([0.2060, 0.0778], dtype=torch.float64)
# tensor([0.7018, 0.7659], dtype=torch.float64)
# tensor([ 1.5318, -0.3903], dtype=torch.float64)
# tensor([ 1.5730, -0.2462], dtype=torch.float64)
# tensor([ 1.5482, -0.0539], dtype=torch.float64)
# tensor([ 1.5814, -0.1419], dtype=torch.float64)
# tensor([1.8452, 0.0834], dtype=torch.float64)
# tensor([-0.1389,  1.1107], dtype=torch.float64)
# tensor([0.1325, 1.1323], dtype=torch.float64)
# tensor([-0.7060,  0.8403], dtype=torch.float64)
# tensor([0.1604, 0.7977], dtype=torch.float64)
# tensor([0.5850, 0.9278], dtype=torch.float64)
# tensor([0.3449, 1.0800], dtype=torch.float64)
# tensor([1.9448, 0.1175], dtype=torch.float64)
# tensor([ 1.8130, -0.0897], dtype=torch.float64)
# tensor([-0.0926,  0.4546], dtype=torch.float64)
# tensor([-0.8915,  0.1715], dtype=torch.float64)
# tensor([ 1.0111, -0.5288], dtype=torch.float64)
# tensor([-0.6805,  0.5087], dtype=torch.float64)
# tensor([0.2083, 0.4591], dtype=torch.float64)
# tensor([ 0.1952, -0.2223], dtype=torch.float64)
# tensor([ 0.3092, -0.0906], dtype=torch.float64)
# tensor([ 0.3202, -0.4238], dtype=torch.float64)
# tensor([ 0.6912, -0.4252], dtype=torch.float64)
# tensor([ 1.1599, -0.3829], dtype=torch.float64)
# tensor([ 0.4144, -0.5255], dtype=torch.float64)
# tensor([ 1.5764, -0.3995], dtype=torch.float64)
# tensor([-0.9605,  0.2018], dtype=torch.float64)
# tensor([-0.6593,  0.7943], dtype=torch.float64)
# tensor([ 1.5908, -0.5233], dtype=torch.float64)
# tensor([1.0340, 0.4231], dtype=torch.float64)
# tensor([0.5773, 0.7490], dtype=torch.float64)
# tensor([-0.0737,  0.9176], dtype=torch.float64)
# tensor([-0.3364,  1.0330], dtype=torch.float64)
# tensor([ 1.3563, -0.3889], dtype=torch.float64)
# tensor([1.9670, 0.0526], dtype=torch.float64)
# tensor([-0.6733,  0.6414], dtype=torch.float64)
# tensor([ 1.0427, -0.4535], dtype=torch.float64)
# tensor([-0.0049,  1.0394], dtype=torch.float64)
# tensor([1.8949, 0.0593], dtype=torch.float64)
# tensor([ 1.5042, -0.2283], dtype=torch.float64)
# tensor([0.7607, 0.0885], dtype=torch.float64)
# tensor([ 0.8453, -0.6398], dtype=torch.float64)
# tensor([-0.6906,  0.7353], dtype=torch.float64)
# tensor([1.0802, 0.2606], dtype=torch.float64)
# tensor([0.6464, 0.6790], dtype=torch.float64)
# tensor([2.0387, 0.3198], dtype=torch.float64)
# tensor([ 0.1747, -0.1947], dtype=torch.float64)
# tensor([ 1.5897, -0.3106], dtype=torch.float64)
# tensor([0.7020, 0.7507], dtype=torch.float64)
# tensor([0.9204, 0.5521], dtype=torch.float64)
# tensor([-0.6680,  0.5509], dtype=torch.float64)
# tensor([ 1.6406, -0.2041], dtype=torch.float64)
# tensor([0.7257, 0.5875], dtype=torch.float64)
# tensor([ 0.9660, -0.4882], dtype=torch.float64)
# tensor([-0.5296,  0.7722], dtype=torch.float64)
# tensor([ 1.2991, -0.5049], dtype=torch.float64)
# tensor([0.8067, 0.4148], dtype=torch.float64)
# tensor([0.0457, 0.3588], dtype=torch.float64)
# tensor([0.1989, 0.0467], dtype=torch.float64)
# tensor([1.0650, 0.3280], dtype=torch.float64)
# tensor([-0.4356,  0.9021], dtype=torch.float64)
# tensor([0.0862, 0.8570], dtype=torch.float64)
# tensor([ 0.9453, -0.1560], dtype=torch.float64)
# tensor([ 0.7711, -0.2948], dtype=torch.float64)
# tensor([0.7705, 0.6021], dtype=torch.float64)
# tensor([ 0.4682, -0.3553], dtype=torch.float64)
# tensor([2.1820, 0.1199], dtype=torch.float64)
# tensor([0.1278, 0.2664], dtype=torch.float64)
# tensor([0.7662, 0.6891], dtype=torch.float64)
# tensor([1.2237, 0.1368], dtype=torch.float64)
# tensor([0.3696, 0.6904], dtype=torch.float64)
# tensor([ 1.0972, -0.5136], dtype=torch.float64)
# tensor([-0.7067,  0.8294], dtype=torch.float64)
# tensor([ 0.6343, -0.3528], dtype=torch.float64)
# tensor([-0.6248,  0.7306], dtype=torch.float64)
# tensor([ 0.8177, -0.5588], dtype=torch.float64)
# tensor([0.8322, 0.1127], dtype=torch.float64)
# tensor([ 0.2906, -0.2183], dtype=torch.float64)
# tensor([-0.9788, -0.0169], dtype=torch.float64)
# tensor([ 1.0026, -0.3044], dtype=torch.float64)
# tensor([-0.0313,  1.0279], dtype=torch.float64)
# tensor([-0.7223,  0.2031], dtype=torch.float64)
# tensor([-0.1744,  1.0190], dtype=torch.float64)
# tensor([0.1580, 0.9890], dtype=torch.float64)
# tensor([ 0.4437, -0.3950], dtype=torch.float64)
# tensor([0.7609, 0.4175], dtype=torch.float64)
# tensor([ 1.7857, -0.1170], dtype=torch.float64)
# tensor([ 1.3741, -0.3546], dtype=torch.float64)
# tensor([0.5891, 1.0156], dtype=torch.float64)
# tensor([-0.0856,  1.0050], dtype=torch.float64)
# tensor([-0.6624,  0.6120], dtype=torch.float64)
# tensor([-1.0105,  0.4882], dtype=torch.float64)
# tensor([-0.9279,  0.0978], dtype=torch.float64)
# tensor([-0.0225,  0.1295], dtype=torch.float64)
# tensor([1.0954, 0.3104], dtype=torch.float64)
# tensor([-0.5432,  0.8839], dtype=torch.float64)
# tensor([1.0334, 0.0570], dtype=torch.float64)
# tensor([-0.7748,  0.8505], dtype=torch.float64)
# tensor([-0.1062,  0.3672], dtype=torch.float64)
# tensor([-0.0178,  1.0459], dtype=torch.float64)
# tensor([-0.4852,  0.7153], dtype=torch.float64)
# tensor([-0.7890,  0.7407], dtype=torch.float64)
# tensor([0.4424, 1.1172], dtype=torch.float64)
# tensor([0.9627, 0.4017], dtype=torch.float64)
# tensor([-0.9939,  0.2958], dtype=torch.float64)
# tensor([ 0.3318, -0.0750], dtype=torch.float64)
# tensor([ 1.9432, -0.1148], dtype=torch.float64)
# tensor([-0.2425,  0.9435], dtype=torch.float64)
# tensor([1.9903, 0.0221], dtype=torch.float64)
# tensor([0.5834, 0.8417], dtype=torch.float64)
# tensor([-1.0306,  0.3561], dtype=torch.float64)
# tensor([ 0.5213, -0.3468], dtype=torch.float64)
# tensor([-0.9141,  0.4889], dtype=torch.float64)
# tensor([0.6544, 0.5765], dtype=torch.float64)
# tensor([0.7341, 0.4287], dtype=torch.float64)
# tensor([ 1.3334, -0.4890], dtype=torch.float64)
# tensor([-0.9371,  0.4766], dtype=torch.float64)
# tensor([ 1.1537, -0.4599], dtype=torch.float64)
# tensor([ 1.7454, -0.0354], dtype=torch.float64)
# tensor([-0.8646,  0.7662], dtype=torch.float64)
# tensor([0.2075, 0.2383], dtype=torch.float64)
# tensor([ 1.2826, -0.3514], dtype=torch.float64)
# tensor([2.0478, 0.1348], dtype=torch.float64)
# tensor([-0.6592,  0.6443], dtype=torch.float64)
# tensor([0.4996, 0.9513], dtype=torch.float64)
# tensor([0.2612, 0.9295], dtype=torch.float64)
# tensor([ 1.3041, -0.5262], dtype=torch.float64)
# tensor([ 0.2766, -0.2676], dtype=torch.float64)
# tensor([1.9847, 0.1988], dtype=torch.float64)
# tensor([0.1148, 0.3714], dtype=torch.float64)
# tensor([ 0.4427, -0.3413], dtype=torch.float64)
# tensor([2.0925, 0.1549], dtype=torch.float64)
# tensor([0.3166, 0.9863], dtype=torch.float64)
# tensor([0.0749, 0.1866], dtype=torch.float64)
# tensor([ 1.0616, -0.0052], dtype=torch.float64)
# tensor([1.8271, 0.1449], dtype=torch.float64)
# tensor([ 1.7734, -0.1927], dtype=torch.float64)
# tensor([0.9650, 0.2636], dtype=torch.float64)
# tensor([ 1.4246, -0.4215], dtype=torch.float64)
# tensor([1.8019, 0.3816], dtype=torch.float64)
# tensor([1.7777, 0.2451], dtype=torch.float64)
# tensor([ 0.9567, -0.4901], dtype=torch.float64)
# tensor([ 1.3872, -0.3201], dtype=torch.float64)
# tensor([1.9518, 0.0180], dtype=torch.float64)
# tensor([-1.0177,  0.0934], dtype=torch.float64)
# tensor([1.0142, 0.2366], dtype=torch.float64)
# tensor([1.0186, 0.0039], dtype=torch.float64)
# tensor([0.2405, 0.1054], dtype=torch.float64)
# tensor([ 0.4747, -0.2798], dtype=torch.float64)
# tensor([1.9758, 0.3114], dtype=torch.float64)
# tensor([ 0.9749, -0.3729], dtype=torch.float64)
# tensor([ 0.1896, -0.2798], dtype=torch.float64)
# tensor([1.8837, 0.2472], dtype=torch.float64)
# tensor([2.0773, 0.1515], dtype=torch.float64)
# tensor([0.1525, 0.4306], dtype=torch.float64)
# tensor([0.8376, 0.0195], dtype=torch.float64)
# tensor([-0.6477,  0.8906], dtype=torch.float64)
# tensor([0.1825, 0.5023], dtype=torch.float64)
# tensor([ 1.2033, -0.4925], dtype=torch.float64)
# tensor([0.8851, 0.4056], dtype=torch.float64)
# tensor([0.8228, 0.4877], dtype=torch.float64)
# tensor([ 1.8732, -0.0070], dtype=torch.float64)
# tensor([-0.5842,  0.6426], dtype=torch.float64)
# tensor([ 0.2454, -0.0560], dtype=torch.float64)
# tensor([ 0.1958, -0.3463], dtype=torch.float64)
# tensor([-0.5905,  0.8383], dtype=torch.float64)
# tensor([1.0789, 0.4326], dtype=torch.float64)
# tensor([ 0.6957, -0.3922], dtype=torch.float64)
# tensor([0.6390, 0.9261], dtype=torch.float64)
# tensor([0.6499, 0.6399], dtype=torch.float64)
# tensor([-0.4291,  0.9818], dtype=torch.float64)
# tensor([0.6421, 0.8468], dtype=torch.float64)
# tensor([0.2678, 0.9860], dtype=torch.float64)
# tensor([1.8661, 0.3650], dtype=torch.float64)
# tensor([0.9280, 0.4443], dtype=torch.float64)
# tensor([-0.5213,  0.8263], dtype=torch.float64)
# tensor([ 1.0512, -0.4453], dtype=torch.float64)
# tensor([1.9416, 0.3826], dtype=torch.float64)
# tensor([0.2685, 0.9132], dtype=torch.float64)
# tensor([-0.5021,  0.8014], dtype=torch.float64)
# tensor([-0.9119,  0.5423], dtype=torch.float64)
# tensor([2.0989, 0.2461], dtype=torch.float64)
# tensor([0.2747, 0.6612], dtype=torch.float64)
# tensor([ 1.1424, -0.5142], dtype=torch.float64)
# tensor([1.1813, 0.3965], dtype=torch.float64)
# tensor([0.1348, 1.1986], dtype=torch.float64)
# tensor([-0.2332,  0.9432], dtype=torch.float64)
# tensor([1.0585, 0.2500], dtype=torch.float64)
# tensor([0.0231, 0.3613], dtype=torch.float64)
# tensor([1.8635, 0.2096], dtype=torch.float64)
# tensor([ 1.1445, -0.4203], dtype=torch.float64)
# tensor([ 0.0967, -0.2447], dtype=torch.float64)
# tensor([1.0118, 0.2680], dtype=torch.float64)
# tensor([ 0.8189, -0.6469], dtype=torch.float64)
# tensor([2.1350, 0.2213], dtype=torch.float64)
# tensor([0.1382, 0.0641], dtype=torch.float64)
# tensor([ 1.1024, -0.4025], dtype=torch.float64)
# tensor([0.8138, 0.5954], dtype=torch.float64)
# tensor([2.0989, 0.1197], dtype=torch.float64)
# tensor([-0.7028,  0.1450], dtype=torch.float64)
# tensor([ 1.4423, -0.2716], dtype=torch.float64)
# tensor([-0.5225,  0.6895], dtype=torch.float64)
# tensor([-0.1397,  0.3307], dtype=torch.float64)
# tensor([0.0979, 0.1171], dtype=torch.float64)
# tensor([ 1.6381, -0.2532], dtype=torch.float64)
# tensor([-0.4111,  0.9836], dtype=torch.float64)
# tensor([-0.6195,  0.5595], dtype=torch.float64)
# tensor([0.9528, 0.2245], dtype=torch.float64)
# tensor([-0.0781,  0.3651], dtype=torch.float64)
# tensor([ 1.0248, -0.3740], dtype=torch.float64)
# tensor([0.3805, 0.9291], dtype=torch.float64)
# tensor([-0.9793,  0.2935], dtype=torch.float64)
# tensor([0.7329, 0.6861], dtype=torch.float64)
# tensor([ 0.2008, -0.2780], dtype=torch.float64)
# tensor([0.1381, 0.0472], dtype=torch.float64)
# tensor([0.9888, 0.2306], dtype=torch.float64)
# tensor([0.1737, 0.9557], dtype=torch.float64)
# tensor([ 0.2154, -0.0552], dtype=torch.float64)
# tensor([0.9599, 0.4015], dtype=torch.float64)
# tensor([0.7397, 0.9006], dtype=torch.float64)
# tensor([0.2184, 0.6053], dtype=torch.float64)
# tensor([-0.2137,  1.1167], dtype=torch.float64)
# tensor([-1.0559,  0.4043], dtype=torch.float64)
# tensor([ 0.9892, -0.4173], dtype=torch.float64)
# tensor([ 1.5816, -0.3200], dtype=torch.float64)
# tensor([-0.1307,  0.9306], dtype=torch.float64)
# tensor([1.8371, 0.2415], dtype=torch.float64)
# tensor([ 1.2273, -0.1682], dtype=torch.float64)
# tensor([0.9555, 0.3699], dtype=torch.float64)
# tensor([1.0962, 0.0815], dtype=torch.float64)
# tensor([0.5927, 0.9502], dtype=torch.float64)
# tensor([2.0950, 0.0691], dtype=torch.float64)
# tensor([-0.4765,  0.8445], dtype=torch.float64)
# tensor([0.7788, 0.6404], dtype=torch.float64)
# tensor([0.0919, 0.5028], dtype=torch.float64)
# tensor([-0.8655,  0.1212], dtype=torch.float64)
# tensor([1.8502, 0.0705], dtype=torch.float64)
# tensor([-0.8043,  0.5459], dtype=torch.float64)
# tensor([ 0.4836, -0.4119], dtype=torch.float64)
# tensor([0.7547, 0.6639], dtype=torch.float64)
# tensor([1.0411, 0.1751], dtype=torch.float64)
# tensor([0.4067, 0.9983], dtype=torch.float64)
# tensor([ 1.3233, -0.3320], dtype=torch.float64)
# tensor([0.3393, 1.1046], dtype=torch.float64)
# tensor([0.3098, 1.0733], dtype=torch.float64)
# tensor([ 1.1314, -0.5389], dtype=torch.float64)
# tensor([0.4643, 0.0478], dtype=torch.float64)
# tensor([0.0748, 0.1442], dtype=torch.float64)
# tensor([ 0.3391, -0.0857], dtype=torch.float64)
# tensor([0.2003, 1.0597], dtype=torch.float64)
# tensor([0.2927, 1.0371], dtype=torch.float64)
# tensor([ 1.5163, -0.1762], dtype=torch.float64)
# tensor([ 0.9589, -0.5375], dtype=torch.float64)
# tensor([0.0799, 0.5899], dtype=torch.float64)
# tensor([ 1.6856, -0.2133], dtype=torch.float64)
# tensor([ 0.7919, -0.4033], dtype=torch.float64)
# tensor([0.8952, 0.5786], dtype=torch.float64)
# tensor([ 0.8446, -0.6058], dtype=torch.float64)
# tensor([-1.1676,  0.0831], dtype=torch.float64)
# tensor([1.9056, 0.0115], dtype=torch.float64)
# tensor([ 1.1792, -0.5806], dtype=torch.float64)
# tensor([-0.8408,  0.4526], dtype=torch.float64)
# tensor([ 1.7533, -0.2911], dtype=torch.float64)
# tensor([-0.7158,  0.8124], dtype=torch.float64)
# tensor([ 1.1367, -0.3948], dtype=torch.float64)
# tensor([1.9284, 0.6530], dtype=torch.float64)
# tensor([ 1.6026, -0.2942], dtype=torch.float64)
# tensor([-0.3316,  0.9804], dtype=torch.float64)
# tensor([ 1.7691, -0.1265], dtype=torch.float64)
# tensor([0.2799, 1.0098], dtype=torch.float64)
# tensor([-1.0972,  0.1382], dtype=torch.float64)
# tensor([-0.5915,  0.7535], dtype=torch.float64)
# tensor([0.7358, 0.7539], dtype=torch.float64)
# tensor([-0.1270,  0.5453], dtype=torch.float64)
# tensor([ 0.8544, -0.5832], dtype=torch.float64)
# tensor([ 1.3727, -0.5353], dtype=torch.float64)
# tensor([-0.9093,  0.3604], dtype=torch.float64)
# tensor([1.9902, 0.1816], dtype=torch.float64)
# tensor([0.3896, 0.8765], dtype=torch.float64)
# tensor([0.4544, 0.8649], dtype=torch.float64)
# tensor([0.9326, 0.5542], dtype=torch.float64)
# tensor([1.1583, 0.2607], dtype=torch.float64)
# tensor([2.0374, 0.4627], dtype=torch.float64)
# tensor([ 1.1770, -0.6090], dtype=torch.float64)
# tensor([ 1.3689, -0.5138], dtype=torch.float64)
# tensor([ 1.2575, -0.3411], dtype=torch.float64)
# tensor([0.6368, 0.8470], dtype=torch.float64)
# tensor([-0.7568,  0.4900], dtype=torch.float64)
# tensor([2.0585, 0.1469], dtype=torch.float64)
# tensor([-0.2493,  0.2979], dtype=torch.float64)
# tensor([ 0.4277, -0.4738], dtype=torch.float64)
# tensor([-1.0884,  0.1884], dtype=torch.float64)
# tensor([ 0.3289, -0.2181], dtype=torch.float64)
# tensor([0.2283, 0.0681], dtype=torch.float64)
# tensor([-0.9471,  0.3485], dtype=torch.float64)
# tensor([ 0.3220, -0.1444], dtype=torch.float64)
# tensor([-0.8587,  0.4244], dtype=torch.float64)
# tensor([ 0.6057, -0.3015], dtype=torch.float64)
# tensor([1.9619, 0.1863], dtype=torch.float64)
# tensor([-0.6849,  0.9864], dtype=torch.float64)
# tensor([0.2541, 0.0258], dtype=torch.float64)
# tensor([-0.9345,  0.0828], dtype=torch.float64)
# tensor([-0.1138,  0.0461], dtype=torch.float64)
# tensor([0.9525, 0.5594], dtype=torch.float64)
# tensor([1.9823, 0.0969], dtype=torch.float64)
# tensor([0.7118, 0.9774], dtype=torch.float64)
# tensor([ 1.2769, -0.6386], dtype=torch.float64)
# tensor([-0.6008,  0.7458], dtype=torch.float64)
# tensor([1.7723, 0.2377], dtype=torch.float64)
# tensor([0.8095, 0.4569], dtype=torch.float64)
# tensor([1.0073, 0.0697], dtype=torch.float64)
# tensor([ 0.8381, -0.3606], dtype=torch.float64)
# tensor([ 0.7330, -0.5953], dtype=torch.float64)
# tensor([1.0205, 0.4203], dtype=torch.float64)
# tensor([-0.0800,  0.3496], dtype=torch.float64)
# tensor([0.7850, 0.3315], dtype=torch.float64)
# tensor([-0.1360,  0.5170], dtype=torch.float64)
# tensor([ 0.2695, -0.1823], dtype=torch.float64)
# tensor([0.4780, 0.8384], dtype=torch.float64)
# tensor([0.2992, 1.0023], dtype=torch.float64)
# tensor([0.3279, 0.7671], dtype=torch.float64)
# tensor([-0.8419,  0.1699], dtype=torch.float64)
# tensor([ 0.2899, -0.1668], dtype=torch.float64)
# tensor([1.7604, 0.0227], dtype=torch.float64)
# tensor([0.1345, 0.3418], dtype=torch.float64)
# tensor([ 0.5166, -0.3727], dtype=torch.float64)
# tensor([-0.0131,  1.0923], dtype=torch.float64)
# tensor([ 1.3309, -0.5919], dtype=torch.float64)
# tensor([0.9773, 0.5393], dtype=torch.float64)
# tensor([0.9125, 0.6478], dtype=torch.float64)
# tensor([ 0.6034, -0.5393], dtype=torch.float64)
# tensor([0.1135, 0.0170], dtype=torch.float64)
# tensor([0.9439, 0.4187], dtype=torch.float64)
# tensor([ 0.4838, -0.5190], dtype=torch.float64)
# tensor([ 0.3378, -0.2254], dtype=torch.float64)
# tensor([0.2423, 0.7935], dtype=torch.float64)
# tensor([ 1.4358, -0.4146], dtype=torch.float64)
# tensor([ 1.4922, -0.3868], dtype=torch.float64)
# tensor([-0.8664,  0.6156], dtype=torch.float64)
# tensor([ 1.6904, -0.1430], dtype=torch.float64)
# tensor([0.8941, 0.5885], dtype=torch.float64)
# tensor([ 0.5373, -0.3979], dtype=torch.float64)
# tensor([0.2347, 0.9436], dtype=torch.float64)
# tensor([ 0.2291, -0.2672], dtype=torch.float64)
# tensor([ 0.9922, -0.3854], dtype=torch.float64)
# tensor([-0.8683,  0.1557], dtype=torch.float64)
# tensor([0.6389, 0.6819], dtype=torch.float64)
# tensor([ 1.0759, -0.4067], dtype=torch.float64)
# tensor([-0.6898,  0.6297], dtype=torch.float64)
# tensor([0.9222, 0.2970], dtype=torch.float64)
# tensor([-0.1644,  0.4396], dtype=torch.float64)
# tensor([-1.0507,  0.2141], dtype=torch.float64)
# tensor([ 0.2389, -0.1593], dtype=torch.float64)
# tensor([1.9881, 0.4201], dtype=torch.float64)
# tensor([ 1.4577, -0.3080], dtype=torch.float64)
# tensor([-0.8066,  0.3378], dtype=torch.float64)
# tensor([ 0.6279, -0.4421], dtype=torch.float64)
# tensor([0.8704, 0.5511], dtype=torch.float64)
# tensor([-1.0491,  0.1644], dtype=torch.float64)
# tensor([ 1.3073, -0.5834], dtype=torch.float64)
# tensor([-0.0185, -0.0985], dtype=torch.float64)
# tensor([0.1686, 0.0820], dtype=torch.float64)
# tensor([ 1.3313, -0.4734], dtype=torch.float64)
# tensor([-0.5314,  0.8786], dtype=torch.float64)
# tensor([ 1.8672, -0.2474], dtype=torch.float64)
# tensor([0.5932, 0.8199], dtype=torch.float64)
# tensor([0.9754, 0.0436], dtype=torch.float64)
# tensor([-0.4883,  0.7177], dtype=torch.float64)
# tensor([0.0355, 0.0606], dtype=torch.float64)
# tensor([0.5571, 0.8186], dtype=torch.float64)
# tensor([-0.9360,  0.2962], dtype=torch.float64)
# tensor([-0.8566,  0.6923], dtype=torch.float64)
# tensor([ 1.7222, -0.3979], dtype=torch.float64)
# tensor([0.1327, 0.8530], dtype=torch.float64)
# tensor([-0.6662,  0.7210], dtype=torch.float64)
# tensor([ 1.2142, -0.4193], dtype=torch.float64)
# tensor([ 1.3912, -0.3796], dtype=torch.float64)
# tensor([0.3974, 0.8297], dtype=torch.float64)
# tensor([ 1.6780, -0.4412], dtype=torch.float64)
# tensor([1.8260, 0.1474], dtype=torch.float64)
# tensor([0.7727, 0.6226], dtype=torch.float64)
# tensor([ 1.4096, -0.3383], dtype=torch.float64)
# tensor([0.0245, 0.1859], dtype=torch.float64)
# tensor([ 0.5530, -0.4660], dtype=torch.float64)
# tensor([ 0.4365, -0.1718], dtype=torch.float64)
# tensor([ 1.5250, -0.3693], dtype=torch.float64)
# tensor([ 0.8075, -0.0530], dtype=torch.float64)
# tensor([-0.1563,  0.8851], dtype=torch.float64)
# tensor([-0.4224,  0.9360], dtype=torch.float64)
# tensor([-0.6511,  0.4897], dtype=torch.float64)
# tensor([0.8041, 0.6807], dtype=torch.float64)
# tensor([-0.5958,  0.6264], dtype=torch.float64)
# tensor([-0.3008,  0.9185], dtype=torch.float64)
# tensor([0.0623, 0.0665], dtype=torch.float64)
# tensor([-1.0396,  0.3941], dtype=torch.float64)
# tensor([0.8484, 0.5175], dtype=torch.float64)
# tensor([ 0.2265, -0.3110], dtype=torch.float64)
# tensor([-0.8800,  0.5044], dtype=torch.float64)
# tensor([1.0176, 0.2407], dtype=torch.float64)
# tensor([-0.7688,  0.4963], dtype=torch.float64)
# tensor([-0.0919,  0.5721], dtype=torch.float64)
# tensor([-0.3050,  0.9363], dtype=torch.float64)
# tensor([-0.8464,  0.4320], dtype=torch.float64)
# tensor([1.8786, 0.4511], dtype=torch.float64)
# tensor([0.2427, 0.8839], dtype=torch.float64)
# tensor([-0.1267,  1.1371], dtype=torch.float64)
# tensor([ 1.3695, -0.3258], dtype=torch.float64)
# tensor([0.8252, 0.6739], dtype=torch.float64)
# tensor([0.9054, 0.3262], dtype=torch.float64)
# tensor([0.9523, 0.6456], dtype=torch.float64)
# tensor([ 1.3703, -0.5318], dtype=torch.float64)
# tensor([ 0.7094, -0.3219], dtype=torch.float64)
# tensor([-0.2484,  0.8662], dtype=torch.float64)
# tensor([0.8966, 0.5401], dtype=torch.float64)
# tensor([-0.0394,  0.3251], dtype=torch.float64)
# tensor([-0.4720,  0.6831], dtype=torch.float64)
# tensor([ 0.3258, -0.2566], dtype=torch.float64)
# tensor([-0.0231,  0.1133], dtype=torch.float64)
# tensor([ 1.5554, -0.4536], dtype=torch.float64)
# tensor([1.9621, 0.1545], dtype=torch.float64)
# tensor([-0.9294,  0.3753], dtype=torch.float64)
# tensor([0.6318, 0.8716], dtype=torch.float64)
# tensor([0.8055, 0.6697], dtype=torch.float64)
# tensor([-0.0889,  1.0591], dtype=torch.float64)
# tensor([-0.9016,  0.4457], dtype=torch.float64)
# tensor([-0.6511,  0.8713], dtype=torch.float64)
# tensor([ 0.2031, -0.1941], dtype=torch.float64)
# tensor([ 1.1694, -0.4371], dtype=torch.float64)
# tensor([ 1.6915, -0.1105], dtype=torch.float64)
# tensor([-0.0236,  0.1531], dtype=torch.float64)
# tensor([ 0.3540, -0.1337], dtype=torch.float64)
# tensor([ 0.7835, -0.4691], dtype=torch.float64)
# tensor([ 1.2508, -0.5039], dtype=torch.float64)
# tensor([ 0.8609, -0.5350], dtype=torch.float64)
# tensor([1.9352, 0.1328], dtype=torch.float64)
# tensor([ 0.2830, -0.0029], dtype=torch.float64)
# tensor([-0.7957,  0.4811], dtype=torch.float64)
# tensor([0.8374, 0.5146], dtype=torch.float64)
# tensor([ 0.7807, -0.6094], dtype=torch.float64)
# tensor([-0.0799,  0.3197], dtype=torch.float64)
# tensor([0.5908, 0.5865], dtype=torch.float64)
# tensor([ 0.4536, -0.3271], dtype=torch.float64)
# tensor([ 1.1307, -0.4847], dtype=torch.float64)
# tensor([2.0011, 0.0232], dtype=torch.float64)
# tensor([0.2070, 0.9686], dtype=torch.float64)
# tensor([1.0585, 0.3958], dtype=torch.float64)
# tensor([-0.3696,  1.0153], dtype=torch.float64)
# tensor([-0.8681,  0.6035], dtype=torch.float64)
# tensor([0.1252, 1.0726], dtype=torch.float64)
# tensor([0.6201, 0.6954], dtype=torch.float64)
# tensor([-0.7174,  0.5587], dtype=torch.float64)
# tensor([-1.0213, -0.0610], dtype=torch.float64)
# tensor([0.7719, 0.5476], dtype=torch.float64)
# tensor([ 0.2773, -0.0910], dtype=torch.float64)
# tensor([1.8273, 0.0276], dtype=torch.float64)
# tensor([ 0.3114, -0.0867], dtype=torch.float64)
# tensor([-0.9625,  0.4246], dtype=torch.float64)
# tensor([0.5584, 0.9662], dtype=torch.float64)
# tensor([0.0089, 0.8419], dtype=torch.float64)
# tensor([1.8420, 0.0821], dtype=torch.float64)
# tensor([0.0256, 0.3149], dtype=torch.float64)
# tensor([0.5663, 0.8800], dtype=torch.float64)
# tensor([ 1.8085, -0.1958], dtype=torch.float64)
# tensor([-0.9333,  0.3934], dtype=torch.float64)
# tensor([-1.0131,  0.2981], dtype=torch.float64)
# tensor([-0.0134,  0.8700], dtype=torch.float64)
# tensor([ 1.0701, -0.4936], dtype=torch.float64)
# tensor([ 1.2797, -0.1807], dtype=torch.float64)
# tensor([ 0.8949, -0.5798], dtype=torch.float64)
# tensor([0.1497, 1.0744], dtype=torch.float64)
# tensor([-0.9764,  0.3400], dtype=torch.float64)
# tensor([ 1.1036, -0.5104], dtype=torch.float64)
# tensor([-0.0126,  0.4227], dtype=torch.float64)
# tensor([2.0988, 0.3136], dtype=torch.float64)
# tensor([-1.1110,  0.0896], dtype=torch.float64)
# tensor([0.9250, 0.1802], dtype=torch.float64)
# tensor([1.8188, 0.1104], dtype=torch.float64)
# tensor([-0.2075,  0.1111], dtype=torch.float64)
# tensor([0.1465, 0.0287], dtype=torch.float64)
# tensor([-0.9501,  0.1563], dtype=torch.float64)
# tensor([ 1.4542, -0.4790], dtype=torch.float64)
# tensor([ 1.5061, -0.2552], dtype=torch.float64)
# tensor([-0.8311,  0.0010], dtype=torch.float64)
# tensor([-0.6158,  0.5744], dtype=torch.float64)
# tensor([-0.1862,  0.5298], dtype=torch.float64)
# tensor([ 1.9298, -0.1371], dtype=torch.float64)
# tensor([0.8943, 0.0987], dtype=torch.float64)
# tensor([ 1.7842, -0.0562], dtype=torch.float64)
# tensor([2.1140, 0.2363], dtype=torch.float64)
# tensor([-0.7270,  0.3869], dtype=torch.float64)
# tensor([-0.0434,  0.5121], dtype=torch.float64)
# tensor([-0.7337,  0.7083], dtype=torch.float64)
# tensor([ 0.7378, -0.5680], dtype=torch.float64)
# tensor([ 0.4010, -0.2309], dtype=torch.float64)
# tensor([0.6016, 0.8162], dtype=torch.float64)
# tensor([ 0.9389, -0.5166], dtype=torch.float64)
# tensor([0.9946, 0.4262], dtype=torch.float64)
# tensor([1.7010, 0.0647], dtype=torch.float64)
# tensor([ 0.4810, -0.4693], dtype=torch.float64)
# tensor([-0.1862,  1.0579], dtype=torch.float64)
# tensor([0.8649, 0.5428], dtype=torch.float64)
# tensor([-0.9248,  0.3746], dtype=torch.float64)
# tensor([ 0.8134, -0.6172], dtype=torch.float64)
# tensor([ 0.4224, -0.4693], dtype=torch.float64)
# tensor([ 1.6356, -0.2539], dtype=torch.float64)
# tensor([ 0.0210, -0.0035], dtype=torch.float64)
# tensor([0.8818, 0.6536], dtype=torch.float64)
# tensor([0.9444, 0.2321], dtype=torch.float64)
# tensor([-0.7694,  0.6682], dtype=torch.float64)
# tensor([ 0.6768, -0.3388], dtype=torch.float64)
# tensor([ 0.3786, -0.3322], dtype=torch.float64)
# tensor([ 0.3956, -0.4335], dtype=torch.float64)
# tensor([0.4262, 0.0151], dtype=torch.float64)
# tensor([-0.9380,  0.4440], dtype=torch.float64)
# tensor([0.5045, 0.7478], dtype=torch.float64)
# tensor([ 1.1728, -0.5136], dtype=torch.float64)
# tensor([-0.3335,  0.9657], dtype=torch.float64)
# tensor([ 1.4802, -0.1167], dtype=torch.float64)
# tensor([0.8726, 0.5841], dtype=torch.float64)
# tensor([ 0.9501, -0.3366], dtype=torch.float64)
# tensor([-0.6374,  1.2131], dtype=torch.float64)
# tensor([0.2636, 0.0444], dtype=torch.float64)
# tensor([ 0.1564, -0.2638], dtype=torch.float64)
# tensor([-1.0308,  0.4257], dtype=torch.float64)
# tensor([0.8091, 0.4604], dtype=torch.float64)
# tensor([ 0.6530, -0.4051], dtype=torch.float64)
# tensor([1.7211, 0.0349], dtype=torch.float64)
# tensor([-0.5580,  0.8333], dtype=torch.float64)
# tensor([0.5183, 0.9587], dtype=torch.float64)
# tensor([0.0927, 1.1682], dtype=torch.float64)
# tensor([ 1.7617, -0.1234], dtype=torch.float64)
# tensor([ 0.1811, -0.0716], dtype=torch.float64)
# tensor([0.1678, 0.8360], dtype=torch.float64)
# tensor([ 0.5746, -0.2237], dtype=torch.float64)
# tensor([ 0.2752, -0.3475], dtype=torch.float64)

# %%
DataLoader(ds, batch_size=50, shuffle=True)
